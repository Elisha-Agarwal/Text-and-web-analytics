# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
text = "A linked list is a linear data structure (like arrays) where each element is a separate object. Each element (that is node) of a list is comprising of two items – the data and a reference to the next node.Types of Linked List "
print(word_tokenize(text))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...
# ['A', 'linked', 'list', 'is', 'a', 'linear', 'data', 'structure', '(', 'like', 'arrays', ')', 'where', 'each', 'element', 'is', 'a', 'separate', 'object', '.', 'Each', 'element', '(', 'that', 'is', 'node', ')', 'of', 'a', 'list', 'is', 'comprising', 'of', 'two', 'items', '–', 'the', 'data', 'and', 'a', 'reference', 'to', 'the', 'next', 'node.Types', 'of', 'Linked', 'List']
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize
text = "A linked list is a linear data structure (like arrays) where each element is a separate object. Each element (that is node) of a list is comprising of two items – the data and a reference to the next node.Types of Linked List "
print(sent_tokenize(text))
# Out:
# ['A linked list is a linear data structure (like arrays) where each element is a separate object.', 'Each element (that is node) of a list is comprising of two items – the data and a reference to the next node.Types of Linked List']

# %%
import nltk
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
from nltk.corpus import stopwords  
from nltk.tokenize import word_tokenize  
  
example_sent = """A linked list is a linear data structure (like arrays) where each element is a separate object. Each element (that is node) of a list is comprising of two items – the data and a reference to the next node.Types of Linked List """
  
stop_words = set(stopwords.words('english'))  
  
word_tokens = word_tokenize(example_sent)  
  
filtered_sentence = [w for w in word_tokens if not w in stop_words]  
  
filtered_sentence = []  
  
for w in word_tokens:  
    if w not in stop_words:  
        filtered_sentence.append(w) 
        
print(filtered_sentence)
# Out:
# ['A', 'linked', 'list', 'linear', 'data', 'structure', '(', 'like', 'arrays', ')', 'element', 'separate', 'object', '.', 'Each', 'element', '(', 'node', ')', 'list', 'comprising', 'two', 'items', '–', 'data', 'reference', 'next', 'node.Types', 'Linked', 'List']

# %%
import nltk
from nltk.corpus import stopwords
set(stopwords.words('greek'))
# Out:
# {'αλλα',
#  'αν',
#  'αντι',
#  'απο',
#  'αυτα',
#  'αυτεσ',
#  'αυτη',
#  'αυτο',
#  'αυτοι',
#  'αυτοσ',
#  'αυτουσ',
#  'αυτων',
#  'αἱ',
#  'αἳ',
#  'αἵ',
#  'αὐτόσ',
#  'αὐτὸς',
#  'αὖ',
#  'γάρ',
#  'γα',
#  'γα^',
#  'γε',
#  'για',
#  'γοῦν',
#  'γὰρ',
#  "δ'",
#  'δέ',
#  'δή',
#  'δαί',
#  'δαίσ',
#  'δαὶ',
#  'δαὶς',
#  'δε',
#  'δεν',
#  "δι'",
#  'διά',
#  'διὰ',
#  'δὲ',
#  'δὴ',
#  'δ’',
#  'εαν',
#  'ειμαι',
#  'ειμαστε',
#  'ειναι',
#  'εισαι',
#  'ειστε',
#  'εκεινα',
#  'εκεινεσ',
#  'εκεινη',
#  'εκεινο',
#  'εκεινοι',
#  'εκεινοσ',
#  'εκεινουσ',
#  'εκεινων',
#  'ενω',
#  'επ',
#  'επι',
#  'εἰ',
#  'εἰμί',
#  'εἰμὶ',
#  'εἰς',
#  'εἰσ',
#  'εἴ',
#  'εἴμι',
#  'εἴτε',
#  'η',
#  'θα',
#  'ισωσ',
#  'κ',
#  'καί',
#  'καίτοι',
#  'καθ',
#  'και',
#  'κατ',
#  'κατά',
#  'κατα',
#  'κατὰ',
#  'καὶ',
#  'κι',
#  'κἀν',
#  'κἂν',
#  'μέν',
#  'μή',
#  'μήτε',
#  'μα',
#  'με',
#  'μεθ',
#  'μετ',
#  'μετά',
#  'μετα',
#  'μετὰ',
#  'μη',
#  'μην',
#  'μἐν',
# ...

# %%
nltk.download('brown')
from nltk.corpus import brown
brown.categories()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
N-Grams

N-grams of texts are extensively used in text mining and natural language processing tasks. 
They are basically a set of co-occurring words within a given window and when computing the 
n-grams you typically move one word forward.

# %%
from nltk import ngrams

sentence = 'A linked list is a linear data structure (like arrays) where each element is a separate object. Each element (that is node) of a list is comprising of two items – the data and a reference to the next node.Types of Linked List '

n = 4
sixgrams = ngrams(sentence.split(), n)

for grams in sixgrams:
    print (grams)
# Out:
# ('A', 'linked', 'list', 'is')
# ('linked', 'list', 'is', 'a')
# ('list', 'is', 'a', 'linear')
# ('is', 'a', 'linear', 'data')
# ('a', 'linear', 'data', 'structure')
# ('linear', 'data', 'structure', '(like')
# ('data', 'structure', '(like', 'arrays)')
# ('structure', '(like', 'arrays)', 'where')
# ('(like', 'arrays)', 'where', 'each')
# ('arrays)', 'where', 'each', 'element')
# ('where', 'each', 'element', 'is')
# ('each', 'element', 'is', 'a')
# ('element', 'is', 'a', 'separate')
# ('is', 'a', 'separate', 'object.')
# ('a', 'separate', 'object.', 'Each')
# ('separate', 'object.', 'Each', 'element')
# ('object.', 'Each', 'element', '(that')
# ('Each', 'element', '(that', 'is')
# ('element', '(that', 'is', 'node)')
# ('(that', 'is', 'node)', 'of')
# ('is', 'node)', 'of', 'a')
# ('node)', 'of', 'a', 'list')
# ('of', 'a', 'list', 'is')
# ('a', 'list', 'is', 'comprising')
# ('list', 'is', 'comprising', 'of')
# ('is', 'comprising', 'of', 'two')
# ('comprising', 'of', 'two', 'items')
# ...
